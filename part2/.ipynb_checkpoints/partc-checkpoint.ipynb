# %%
# ========== CONFIG & IMPORTS ==========
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp
import seaborn

# File paths
PRICES_CSV = "../spx100_prices.csv"              # Daily adjusted prices (with 'Date' column)
SECTOR_CSV = "ticker_industries.csv"          # Ticker -> Sector mapping

# Parameters
LOOKBACK_MONTHS = [3, 2, 1]                   # Try different momentum windows
MAX_SECTOR_WEIGHT = 0.25                      # Sector max cap
MAX_STOCK_WEIGHT = 0.05                       # Individual stock cap
ALPHA = 0.95
ANNUAL_TRADING_DAYS = 252
RISK_FREE_RATE = 0.0

# %%
# Load prices
prices = pd.read_csv(PRICES_CSV, parse_dates=["Date"], index_col="Date").sort_index()
print("✅ Prices Data (first 5 rows):")
display(prices.head())

# Load sector classification
sector_df = pd.read_csv(SECTOR_CSV)
print("\n✅ Sector Mapping (first 5 rows):")
display(sector_df.head())

# Print a sample of tickers with sectors
print("\n✅ Sample Ticker-to-Sector Mapping:")
print(sector_df.groupby("Sector")["Ticker"].apply(list).head(10))
# Out:
# ✅ Prices Data (first 5 rows):
#             AAPL  ABBV    ABT    ACN       ADBE    AIG   AMD   AMGN    AMT  \
# Date
# 2010-01-04  6.43   NaN  18.53  31.65  37.090000  16.45  9.70  39.91  32.62
# 2010-01-05  6.44   NaN  18.38  31.85  37.700000  16.15  9.71  39.57  33.16
# 2010-01-06  6.34   NaN  18.48  32.18  37.619999  16.04  9.57  39.27  33.34
# 2010-01-07  6.33   NaN  18.63  32.15  36.889999  15.73  9.47  38.91  33.25
# 2010-01-08  6.37   NaN  18.73  32.03  36.689999  16.15  9.43  39.26  33.31
#
#             AMZN  ...    TXN    UNH    UNP    UPS    USB      V     VZ    WFC  \
# Date              ...
# 2010-01-04  6.70  ...  17.41  24.92  23.46  35.22  14.39  19.72  14.16  18.23
# 2010-01-05  6.73  ...  17.31  24.88  23.78  35.28  14.76  19.49  14.19  18.73
# 2010-01-06  6.61  ...  17.19  25.13  23.82  35.02  14.91  19.23  13.78  18.75
# 2010-01-07  6.50  ...  17.24  26.09  23.61  34.75  15.20  19.41  13.70  19.43
# 2010-01-08  6.68  ...  17.63  25.85  24.41  36.42  15.23  19.46  13.71  19.25
#
#               WMT    XOM
# Date
# 2010-01-04  13.02  38.57
# 2010-01-05  12.89  38.72
# 2010-01-06  12.86  39.05
# 2010-01-07  12.87  38.93
# 2010-01-08  12.80  38.78
#
# [5 rows x 101 columns]
# ✅ Sector Mapping (first 5 rows):
#   Ticker              Company      Sector                         Industry
# 0   AAPL           Apple Inc.  Technology             Consumer Electronics
# 1   ABBV          AbbVie Inc.  Healthcare     Drug Manufacturers - General
# 2    ABT  Abbott Laboratories  Healthcare                Medical - Devices
# 3    ACN        Accenture plc  Technology  Information Technology Services
# 4   ADBE           Adobe Inc.  Technology        Software - Infrastructure
# ✅ Sample Ticker-to-Sector Mapping:
# Sector
# Basic Materials                                                       [LIN]
# Communication Services    [CHTR, CMCSA, DIS, GOOG, GOOGL, META, NFLX, T,...
# Consumer Cyclical           [AMZN, BKNG, GM, HD, LOW, MCD, NKE, SBUX, TSLA]
# Consumer Defensive          [CL, COST, KO, MDLZ, MO, PEP, PG, PM, TGT, WMT]
# Energy                                                      [COP, CVX, XOM]
# Financial Services        [AIG, AXP, BAC, BK, BLK, C, COF, GS, JPM, MA, ...
# Healthcare                [ABBV, ABT, AMGN, BMY, CVS, DHR, GILD, ISRG, J...
# Industrials               [BA, CAT, DE, EMR, FDX, GD, GE, HON, LMT, MMM,...
# Real Estate                                                      [AMT, SPG]
# Technology                [AAPL, ACN, ADBE, AMD, AVGO, CRM, CSCO, IBM, I...
# Name: Ticker, dtype: object

# %%
# Define monthly and quarterly rebalance dates (last trading day of month/quarter)
monthly_rebalance_dates = prices.resample('ME').last().index
quarterly_rebalance_dates = prices.resample('QE').last().index

print("📅 Monthly Rebalance Dates (first 5):")
display(monthly_rebalance_dates[:5])

print("\n📅 Quarterly Rebalance Dates (first 5):")
display(quarterly_rebalance_dates[:5])
# Out:
# 📅 Monthly Rebalance Dates (first 5):
# DatetimeIndex(['2010-01-31', '2010-02-28', '2010-03-31', '2010-04-30',
#                '2010-05-31'],
#               dtype='datetime64[ns]', name='Date', freq='ME')
# 📅 Quarterly Rebalance Dates (first 5):
# DatetimeIndex(['2010-03-31', '2010-06-30', '2010-09-30', '2010-12-31',
#                '2011-03-31'],
#               dtype='datetime64[ns]', name='Date', freq='QE-DEC')

# %%
def run_backtest(prices, rebalance_dates, momentum_days, strategy_label):
    portfolio_returns = []
    turnover_list = []

    prev_weights = pd.Series(0, index=prices.columns)

    for i in range(1, len(rebalance_dates)):
        start_date = rebalance_dates[i - 1]
        end_date = rebalance_dates[i]

        price_slice = prices.loc[:start_date].dropna(axis=1, how='any')
        if len(price_slice) < momentum_days:
            continue

        # Compute momentum
        momentum = price_slice.iloc[-1] / price_slice.iloc[-momentum_days] - 1
        momentum = momentum.dropna()

        # Mean & cov for MV optimization
        returns_window = price_slice[momentum.index].pct_change().dropna()
        mu = returns_window.mean()
        Sigma = returns_window.cov()

        # Optimization
        w = cp.Variable(len(mu))
        objective = cp.Maximize(mu.values @ w - 0.5 * cp.quad_form(w, Sigma.values))
        constraints = [cp.sum(w) == 1, w >= 0, w <= MAX_STOCK_WEIGHT]
        prob = cp.Problem(objective, constraints)
        prob.solve()

        weights = pd.Series(w.value, index=mu.index)
        weights = weights / weights.sum()

        # Calculate turnover and cost
        turnover = np.abs(weights - prev_weights[weights.index]).sum()
        cost = turnover * 0.001  # 10 bps (0.1%) total round-trip
        turnover_list.append(turnover)

        # Calculate period returns
        period_prices = prices.loc[start_date:end_date, weights.index]
        period_returns = period_prices.pct_change().dropna()
        weighted_returns = (period_returns * weights).sum(axis=1)

        # Apply cost on first day
        if not weighted_returns.empty:
            weighted_returns.iloc[0] -= cost

        portfolio_returns.append(weighted_returns)
        prev_weights = weights

    returns = pd.concat(portfolio_returns)
    avg_turnover = np.mean(turnover_list)
    print(f"📉 Average turnover per rebalance for {strategy_label}: {avg_turnover:.2%}")

    return returns



# Run both monthly and quarterly momentum strategies
momentum_days = 63  # ~3 months
monthly_returns = run_backtest(prices, monthly_rebalance_dates, momentum_days, "Monthly MV Momentum")
quarterly_returns = run_backtest(prices, quarterly_rebalance_dates, momentum_days, "Quarterly MV Momentum")

# Benchmark: equal-weight SPX portfolio (no rebalance)
equal_weight = 1 / prices.shape[1]
benchmark_returns = prices.pct_change().dropna().mean(axis=1)

# Combine
strategy_df = pd.DataFrame({
    "Monthly": monthly_returns,
    "Quarterly": quarterly_returns,
    "SPX Equal-Weight": benchmark_returns
}).dropna()

# Combine
strategy_df = pd.DataFrame({
    "Monthly": monthly_returns,
    "Quarterly": quarterly_returns,
    "SPX Equal-Weight": benchmark_returns
}).dropna()

# Save daily and cumulative returns
strategy_df.to_csv("daily_strategy_returns.csv")
cumulative = (1 + strategy_df).cumprod()
cumulative.to_csv("cumulative_strategy_returns.csv")


# Plot
cumulative.plot(figsize=(12, 6), title="📈 Strategy Performance vs. Benchmark")
plt.ylabel("Portfolio Value (Growth of $1)")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_62863/1881139963.py:41: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   period_returns = period_prices.pct_change().dropna()
# 📉 Average turnover per rebalance for Monthly MV Momentum: 13.36%

# %%
def run_cvar_backtest(prices, rebalance_dates, momentum_days, label, alpha=ALPHA):
    portfolio_returns = []
    prev_weights = pd.Series(0, index=prices.columns)

    for i in range(1, len(rebalance_dates)):
        start_date = rebalance_dates[i - 1]
        end_date = rebalance_dates[i]

        price_slice = prices.loc[:start_date].dropna(axis=1, how='any')
        if len(price_slice) < momentum_days:
            continue

        # Momentum
        momentum = price_slice.iloc[-1] / price_slice.iloc[-momentum_days] - 1
        momentum = momentum.dropna()

        returns_window = price_slice[momentum.index].pct_change().dropna()
        X = returns_window.values

        n, m = X.shape
        w = cp.Variable(m)
        z = cp.Variable(n)
        var = cp.Variable()

        # CVaR objective
        cvar_obj = var + (1 / ((1 - alpha) * n)) * cp.sum(z)

        constraints = [
            cp.sum(w) == 1,
            w >= 0,
            w <= MAX_STOCK_WEIGHT,
            z >= 0,
            z >= -X @ w - var
        ]

        prob = cp.Problem(cp.Minimize(cvar_obj), constraints)
        prob.solve()

        weights = pd.Series(w.value, index=momentum.index)
        weights = weights / weights.sum()

        # Transaction cost
        turnover = np.abs(weights - prev_weights[weights.index]).sum()
        cost = turnover * 0.0001

        # Forward returns
        period_prices = prices.loc[start_date:end_date, weights.index]
        period_returns = period_prices.pct_change().dropna()
        weighted_returns = (period_returns * weights).sum(axis=1)
        weighted_returns.iloc[0] -= cost
        portfolio_returns.append(weighted_returns)

        prev_weights = weights

    return pd.concat(portfolio_returns)


# Run CVaR variant
cvar_returns = run_cvar_backtest(prices, monthly_rebalance_dates, momentum_days, "Monthly CVaR")

# Merge into final performance table
strategy_df["Monthly CVaR"] = cvar_returns
strategy_df = strategy_df.dropna()

# Cumulative plot
(1 + strategy_df).cumprod().plot(figsize=(12, 6), title="📊 Strategy Performance (Including CVaR)")
plt.ylabel("Portfolio Value (Growth of $1)")
plt.grid(True)
plt.show()

# 🧾 Summary Stats
def max_drawdown(series):
    cum = (1 + series).cumprod()
    peak = cum.cummax()
    drawdown = (cum - peak) / peak
    return drawdown.min()

summary = pd.DataFrame(index=strategy_df.columns)
summary["Total Return"] = strategy_df.add(1).prod() - 1
summary["Annualized Return"] = strategy_df.mean() * ANNUAL_TRADING_DAYS
summary["Annualized Volatility"] = strategy_df.std() * np.sqrt(ANNUAL_TRADING_DAYS)
summary["Sharpe Ratio"] = summary["Annualized Return"] / summary["Annualized Volatility"]
summary["Max Drawdown"] = strategy_df.apply(max_drawdown)

# 📋 Show results
import seaborn as sns
import matplotlib.pyplot as plt
display(summary.style.format("{:.2%}").background_gradient(cmap='RdYlGn'))
# Out:
# /tmp/ipykernel_20387/1523815561.py:48: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   period_returns = period_prices.pct_change().dropna()
# /home/zech/Desktop/Work Space - Linux/eToro/quantprogram2025/venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 86
#      83 summary["Max Drawdown"] = strategy_df.apply(max_drawdown)
#      85 # 📋 Show results
# ---> 86 import seaborn as sns
#      87 import matplotlib.pyplot as plt
#      88 display(summary.style.format("{:.2%}").background_gradient(cmap='RdYlGn'))
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Run CVaR strategy with Quarterly Rebalancing
cvar_q_returns = run_cvar_backtest(prices, quarterly_rebalance_dates, momentum_days, "Quarterly CVaR")
strategy_df["Quarterly CVaR"] = cvar_q_returns

# Align all strategies by dropping rows with any missing data
strategy_df = strategy_df.dropna()

# 📈 Plot cumulative performance
(1 + strategy_df).cumprod().plot(figsize=(12, 6), title="Strategy Performance Comparison")
plt.ylabel("Growth of $1")
plt.grid(True)
plt.show()

# 📊 Summary performance metrics
summary = pd.DataFrame(index=strategy_df.columns)
summary["Total Return"] = strategy_df.add(1).prod() - 1
summary["Annualized Return"] = strategy_df.mean() * ANNUAL_TRADING_DAYS
summary["Annualized Volatility"] = strategy_df.std() * np.sqrt(ANNUAL_TRADING_DAYS)
summary["Sharpe Ratio"] = summary["Annualized Return"] / summary["Annualized Volatility"]
summary["Max Drawdown"] = strategy_df.apply(max_drawdown)

# 📋 Display summary
display(summary.style.format("{:.2%}").background_gradient(cmap="RdYlGn"))
# Out:
# /tmp/ipykernel_20387/1523815561.py:48: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   period_returns = period_prices.pct_change().dropna()
# <style type="text/css">
# #T_cfbde_row0_col0 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_cfbde_row0_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_cfbde_row0_col2 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_cfbde_row0_col3 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_cfbde_row0_col4, #T_cfbde_row3_col3 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_cfbde_row1_col0, #T_cfbde_row1_col1, #T_cfbde_row1_col2, #T_cfbde_row2_col3, #T_cfbde_row3_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_cfbde_row1_col3 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_cfbde_row1_col4, #T_cfbde_row3_col0, #T_cfbde_row3_col1, #T_cfbde_row3_col2, #T_cfbde_row4_col0, #T_cfbde_row4_col1, #T_cfbde_row4_col2, #T_cfbde_row4_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_cfbde_row2_col0 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_cfbde_row2_col1 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_cfbde_row2_col2 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_cfbde_row2_col4 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_cfbde_row4_col4 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cfbde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfbde_level0_col0" class="col_heading level0 col0" >Total Return</th>
#       <th id="T_cfbde_level0_col1" class="col_heading level0 col1" >Annualized Return</th>
#       <th id="T_cfbde_level0_col2" class="col_heading level0 col2" >Annualized Volatility</th>
#       <th id="T_cfbde_level0_col3" class="col_heading level0 col3" >Sharpe Ratio</th>
#       <th id="T_cfbde_level0_col4" class="col_heading level0 col4" >Max Drawdown</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfbde_level0_row0" class="row_heading level0 row0" >Monthly</th>
#       <td id="T_cfbde_row0_col0" class="data row0 col0" >112.66%</td>
#       <td id="T_cfbde_row0_col1" class="data row0 col1" >20.23%</td>
#       <td id="T_cfbde_row0_col2" class="data row0 col2" >20.83%</td>
#       <td id="T_cfbde_row0_col3" class="data row0 col3" >97.12%</td>
#       <td id="T_cfbde_row0_col4" class="data row0 col4" >-32.87%</td>
#     </tr>
#     <tr>
#       <th id="T_cfbde_level0_row1" class="row_heading level0 row1" >Quarterly</th>
#       <td id="T_cfbde_row1_col0" class="data row1 col0" >117.73%</td>
#       <td id="T_cfbde_row1_col1" class="data row1 col1" >20.82%</td>
#       <td id="T_cfbde_row1_col2" class="data row1 col2" >20.92%</td>
#       <td id="T_cfbde_row1_col3" class="data row1 col3" >99.50%</td>
#       <td id="T_cfbde_row1_col4" class="data row1 col4" >-32.98%</td>
#     </tr>
#     <tr>
#       <th id="T_cfbde_level0_row2" class="row_heading level0 row2" >SPX Equal-Weight</th>
#       <td id="T_cfbde_row2_col0" class="data row2 col0" >96.09%</td>
#       <td id="T_cfbde_row2_col1" class="data row2 col1" >17.34%</td>
#       <td id="T_cfbde_row2_col2" class="data row2 col2" >15.62%</td>
#       <td id="T_cfbde_row2_col3" class="data row2 col3" >110.99%</td>
#       <td id="T_cfbde_row2_col4" class="data row2 col4" >-23.72%</td>
#     </tr>
#     <tr>
#       <th id="T_cfbde_level0_row3" class="row_heading level0 row3" >Monthly CVaR</th>
#       <td id="T_cfbde_row3_col0" class="data row3 col0" >48.62%</td>
#       <td id="T_cfbde_row3_col1" class="data row3 col1" >10.19%</td>
#       <td id="T_cfbde_row3_col2" class="data row3 col2" >11.87%</td>
#       <td id="T_cfbde_row3_col3" class="data row3 col3" >85.81%</td>
#       <td id="T_cfbde_row3_col4" class="data row3 col4" >-14.86%</td>
#     </tr>
#     <tr>
#       <th id="T_cfbde_level0_row4" class="row_heading level0 row4" >Quarterly CVaR</th>
#       <td id="T_cfbde_row4_col0" class="data row4 col0" >48.54%</td>
#       <td id="T_cfbde_row4_col1" class="data row4 col1" >10.18%</td>
#       <td id="T_cfbde_row4_col2" class="data row4 col2" >11.88%</td>
#       <td id="T_cfbde_row4_col3" class="data row4 col3" >85.66%</td>
#       <td id="T_cfbde_row4_col4" class="data row4 col4" >-14.97%</td>
#     </tr>
#   </tbody>
# </table>
